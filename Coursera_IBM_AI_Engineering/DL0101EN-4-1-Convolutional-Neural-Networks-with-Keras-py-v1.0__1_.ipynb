# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Convolutional Neural Networks with Keras</font></h1>

# %% [markdown]
# In this lab, we will learn how to use the Keras library to build convolutional neural networks. We will also use the popular MNIST dataset and we will compare our results to using a conventional neural network.

# %% [markdown]
# <h2>Convolutional Neural Networks with Keras</h2>
#
# <h3>Objective for this Notebook<h3>
# <h5> 1. How to use the Keras library to build convolutional neural networks.</h5>
# <h5> 2. Convolutional Neural Network with One Convolutional and Pooling Layers.</h5>
# <h5> 3. Convolutional Neural Network with Two Convolutional and Pooling Layers.</h5>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item41">Import Keras and Packages</a>
# 2. <a href="#item42">Convolutional Neural Network with One Convolutional and Pooling Layers</a>
# 3. <a href="#item43">Convolutional Neural Network with Two Convolutional and Pooling Layers</a>
#
# </font>
# </div>

# %% [markdown]
# <a id='item41'></a>

# %% [markdown]
# ## Import Keras and Packages

# %% [markdown]
# Let's start by importing the keras libraries and the packages that we would need to build a neural network.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical
# Out:
# 2021-10-12 13:37:20.393609: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# When working with convolutional neural networks in particular, we will need additional packages.

# %%
from keras.layers.convolutional import Conv2D # to add convolutional layers
from keras.layers.convolutional import MaxPooling2D # to add pooling layers
from keras.layers import Flatten # to flatten data for fully connected layers

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
tf.keras.backend.clear_session()
physical_devices = tf.config.list_physical_devices('GPU') 
for device in physical_devices:
    tf.config.experimental.set_memory_growth(device, True)
# Out:
# 2021-10-12 13:37:39.159037: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-12 13:37:39.159491: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-10-12 13:37:39.190877: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:37:39.191251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:08:00.0 name: NVIDIA GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.815GHz coreCount: 40 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-10-12 13:37:39.191264: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-12 13:37:39.208709: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-10-12 13:37:39.208740: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-10-12 13:37:39.218887: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-10-12 13:37:39.221317: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-10-12 13:37:39.239267: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-10-12 13:37:39.241701: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-10-12 13:37:39.272513: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-10-12 13:37:39.272644: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:37:39.273033: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:37:39.273341: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0

# %% [markdown]
# <a id='item42'></a>

# %% [markdown]
# ## Convolutional Layer with One set of convolutional and pooling layers

# %%
# import data
from keras.datasets import mnist

# load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# reshape to be [samples][pixels][width][height]
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %% [markdown]
# Let's normalize the pixel values to be between 0 and 1

# %%
X_train = X_train / 255 # normalize training data
X_test = X_test / 255 # normalize test data

# %% [markdown]
# Next, let's convert the target variable into binary categories

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %% [markdown]
# Next, let's define a function that creates our model. Let's start with one set of convolutional and pooling layers.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Finally, let's call the function to create the model, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# 2021-10-12 13:39:37.515998: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-12 13:39:37.516547: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-10-12 13:39:37.516779: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:39:37.517447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:08:00.0 name: NVIDIA GeForce RTX 2070 SUPER computeCapability: 7.5
# coreClock: 1.815GHz coreCount: 40 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-10-12 13:39:37.517476: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-12 13:39:37.517505: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-10-12 13:39:37.517522: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-10-12 13:39:37.517538: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-10-12 13:39:37.517554: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-10-12 13:39:37.517569: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-10-12 13:39:37.517584: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-10-12 13:39:37.517600: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-10-12 13:39:37.517682: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:39:37.518167: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:39:37.518581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-10-12 13:39:37.518850: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-10-12 13:39:38.098558: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-10-12 13:39:38.098583: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-10-12 13:39:38.098588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-10-12 13:39:38.098965: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:39:38.099325: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:39:38.099655: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-12 13:39:38.099966: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6923 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2070 SUPER, pci bus id: 0000:08:00.0, compute capability: 7.5)
# 2021-10-12 13:39:38.195528: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-10-12 13:39:38.197473: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3599830000 Hz
# Epoch 1/10
# 2021-10-12 13:39:38.423783: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-10-12 13:39:38.631339: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-10-12 13:39:39.533087: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2021-10-12 13:39:39.553328: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 300/300 - 3s - loss: 0.2914 - accuracy: 0.9171 - val_loss: 0.1061 - val_accuracy: 0.9695
# Epoch 2/10
# 300/300 - 0s - loss: 0.0874 - accuracy: 0.9744 - val_loss: 0.0690 - val_accuracy: 0.9779
# Epoch 3/10
# 300/300 - 0s - loss: 0.0599 - accuracy: 0.9824 - val_loss: 0.0558 - val_accuracy: 0.9808
# Epoch 4/10
# 300/300 - 0s - loss: 0.0460 - accuracy: 0.9864 - val_loss: 0.0451 - val_accuracy: 0.9848
# Epoch 5/10
# 300/300 - 0s - loss: 0.0368 - accuracy: 0.9887 - val_loss: 0.0531 - val_accuracy: 0.9824
# Epoch 6/10
# 300/300 - 0s - loss: 0.0312 - accuracy: 0.9904 - val_loss: 0.0421 - val_accuracy: 0.9856
# Epoch 7/10
# 300/300 - 0s - loss: 0.0249 - accuracy: 0.9924 - val_loss: 0.0399 - val_accuracy: 0.9853
# Epoch 8/10
# 300/300 - 0s - loss: 0.0213 - accuracy: 0.9935 - val_loss: 0.0412 - val_accuracy: 0.9863
# Epoch 9/10
# 300/300 - 0s - loss: 0.0182 - accuracy: 0.9944 - val_loss: 0.0442 - val_accuracy: 0.9850
# Epoch 10/10
# 300/300 - 0s - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.0407 - val_accuracy: 0.9876
# Accuracy: 0.9876000285148621
#  Error: 1.239997148513794

# %% [markdown]
# * * *

# %% [markdown]
# <a id='item43'></a>

# %% [markdown]
# ## Convolutional Layer with two sets of convolutional and pooling layers

# %% [markdown]
# Let's redefine our convolutional model so that it has two convolutional and pooling layers instead of just one layer of each.

# %%
def convolutional_model():
    
    # create model
    model = Sequential()
    model.add(Conv2D(16, (5, 5), activation='relu', input_shape=(28, 28, 1)))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
    
    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %% [markdown]
# Now, let's call the function to create our new convolutional neural network, and then let's train it and evaluate it.

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 1s - loss: 0.5058 - accuracy: 0.8533 - val_loss: 0.1714 - val_accuracy: 0.9487
# Epoch 2/10
# 300/300 - 0s - loss: 0.1350 - accuracy: 0.9591 - val_loss: 0.0870 - val_accuracy: 0.9747
# Epoch 3/10
# 300/300 - 0s - loss: 0.0921 - accuracy: 0.9715 - val_loss: 0.0660 - val_accuracy: 0.9789
# Epoch 4/10
# 300/300 - 0s - loss: 0.0725 - accuracy: 0.9776 - val_loss: 0.0657 - val_accuracy: 0.9786
# Epoch 5/10
# 300/300 - 0s - loss: 0.0618 - accuracy: 0.9812 - val_loss: 0.0484 - val_accuracy: 0.9829
# Epoch 6/10
# 300/300 - 0s - loss: 0.0528 - accuracy: 0.9836 - val_loss: 0.0486 - val_accuracy: 0.9825
# Epoch 7/10
# 300/300 - 0s - loss: 0.0483 - accuracy: 0.9852 - val_loss: 0.0458 - val_accuracy: 0.9847
# Epoch 8/10
# 300/300 - 0s - loss: 0.0424 - accuracy: 0.9870 - val_loss: 0.0402 - val_accuracy: 0.9873
# Epoch 9/10
# 300/300 - 1s - loss: 0.0395 - accuracy: 0.9880 - val_loss: 0.0506 - val_accuracy: 0.9843
# Epoch 10/10
# 300/300 - 0s - loss: 0.0350 - accuracy: 0.9890 - val_loss: 0.0371 - val_accuracy: 0.9880
# Accuracy: 0.9879999756813049
#  Error: 1.2000024318695068

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by [Alex Aklson](https://www.linkedin.com/in/aklson?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork-20718188&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork-20718188&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                          |
# | ----------------- | ------- | ---------- | ----------------------------------------------------------- |
# | 2020-09-21        | 2.0     | Srishti    | Migrated Lab to Markdown and added to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# This notebook is part of a course on **Coursera** called _Introduction to Deep Learning & Neural Networks with Keras_. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0101EN_Coursera_Week4_LAB1).

# %% [markdown]
# <hr>
#
# Copyright © 2019 [IBM Developer Skills Network](https://cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork-20718188&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork-20718188&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork-20718188&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork-20718188&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork-20718188&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork-20718188&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
